# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd. read_csv("Salary_Dataset_DataScienceLovers.csv")
df
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %% [markdown]
# understanding the data

# %%
df.shape
# Out:
# (22770, 8)

# %%
df.describe()
# Out:
#              Rating        Salary  Salaries Reported
# count  22770.000000  2.277000e+04       22770.000000
# mean       3.918213  6.953872e+05           1.855775
# std        0.519675  8.843990e+05           6.823668
# min        1.000000  2.112000e+03           1.000000
# 25%        3.700000  3.000000e+05           1.000000
# 50%        3.900000  5.000000e+05           1.000000
# 75%        4.200000  9.000000e+05           1.000000
# max        5.000000  9.000000e+07         361.000000

# %%
df.dtypes
# Out:
# Rating               float64
# Company Name             str
# Job Title                str
# Salary                 int64
# Salaries Reported      int64
# Location                 str
# Employment Status        str
# Job Roles                str
# dtype: object

# %%
df[df['Salary'] == df['Salary'].min()]
df[df['Salary'] == df['Salary'].max()]
# Out:
#        Rating       Company Name                            Job Title  \
# 18635     3.6  Thapar University  Software Development Engineer (SDE)
#
#          Salary  Salaries Reported   Location Employment Status Job Roles
# 18635  90000000                  1  New Delhi         Full Time       SDE

# %%
# How many people are apointed for each unique job title?
df.groupby('Job Title').size()
# Out:
# Job Title
# "ORACLE DBA"                                 2
# .NET Developer, Python                       1
# .NET/Android Developer                       1
# AEM Front End Developer - Intern             1
# ASAP Software Development Engineer           1
#                                             ..
# Web Developer Contractor                    12
# Web Developer, Python Developer              1
# Web Developer/Android Developer - Intern     1
# Xamarin Mobile Developer                     1
# oracle dba                                   1
# Length: 1080, dtype: int64

# %%
df[df['Job Title'] == 'Software Development Engineer (SDE)']
# Out:
#        Rating        Company Name                            Job Title  \
# 11865     4.1            Flipkart  Software Development Engineer (SDE)
# 11879     4.0                Self  Software Development Engineer (SDE)
# 11881     3.9             Quinbay  Software Development Engineer (SDE)
# 11882     3.9    Publicis Sapient  Software Development Engineer (SDE)
# 11884     3.6         Micro Focus  Software Development Engineer (SDE)
# ...       ...                 ...                                  ...
# 19436     3.9                  Mr  Software Development Engineer (SDE)
# 19437     3.9  Naresh Kumar & Co.  Software Development Engineer (SDE)
# 19438     4.0               Nones  Software Development Engineer (SDE)
# 19439     3.9                Xbjd  Software Development Engineer (SDE)
# 19440     4.5              Muskan  Software Development Engineer (SDE)
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df[df['Job Title'] == 'Software Development Engineer']
# Out:
#        Rating                  Company Name                      Job Title  \
# 11863     4.1                         Shell  Software Development Engineer
# 11864     4.3                          314e  Software Development Engineer
# 11867     3.1                      Conduent  Software Development Engineer
# 11868     4.9                  MMACH Design  Software Development Engineer
# 11870     4.3             Intel Corporation  Software Development Engineer
# ...       ...                           ...                            ...
# 19031     3.9                         Kiran  Software Development Engineer
# 19033     4.1                     Accenture  Software Development Engineer
# 19035     3.8                          PayU  Software Development Engineer
# 19036     3.0              Bojan Manojlović  Software Development Engineer
# 19037     3.8  Neeyamo Enterprise Solutions  Software Development Engineer
#
# ...

# %%
df[df['Job Title'] == 'Senior Android Developer']
# Out:
#       Rating                  Company Name                 Job Title   Salary  \
# 594      4.1                     Accenture  Senior Android Developer   700000
# 595      3.8  3Embed Software Technologies  Senior Android Developer   360000
# 597      3.3                       Infosys  Senior Android Developer   600000
# 598      3.7                        BYJU'S  Senior Android Developer  1700000
# 599      4.0                  Y Media Labs  Senior Android Developer  2000000
# ...      ...                           ...                       ...      ...
# 2937     3.7              HCL Technologies  Senior Android Developer  1800000
# 2938     3.6                 Tech Mahindra  Senior Android Developer   900000
# 2939     3.8                           LTI  Senior Android Developer  1000000
# 2940     3.7                       Virtusa  Senior Android Developer   800000
# 2941     3.6             KPIT Technologies  Senior Android Developer   700000
#
# ...

# %%
sns.scatterplot(data=df, x='Salaries Reported', y='Rating')
# Out:
# <Axes: xlabel='Salaries Reported', ylabel='Rating'>

# %%
df[df["Salaries Reported"] > 250]
# Out:
#        Rating Company Name                            Job Title   Salary  \
# 12294     3.8       Amazon  Software Development Engineer (SDE)  1188000
# 12342     3.8       Amazon        Software Development Engineer  5700000
# 19813     3.3      Infosys                        Test Engineer  1104000
# 20344     3.3      Infosys                         Test Analyst   852000
# 20773     3.3      Infosys                        Test Engineer   100000
# 21714     3.3      Infosys                         Test Analyst   100000
#
#        Salaries Reported   Location Employment Status Job Roles
# 12294                291  Bangalore         Full Time       SDE
# 12342                353  Bangalore         Full Time       SDE
# 19813                361  Hyderabad         Full Time   Testing
# 20344                280  Hyderabad         Full Time   Testing
# 20773                331  Bangalore         Full Time   Testing
# 21714                263  Bangalore         Full Time   Testing

# %%
df[df['Salary'] >= 900000]
# Out:
#        Rating                                Company Name  \
# 2         4.0                                   Unacademy
# 18        4.0                                 J.P. Morgan
# 63        5.0                               powerplay app
# 71        3.3                  Datamatics Global Services
# 82        4.3                            Ashwin Infotrron
# ...       ...                                         ...
# 22681     4.0                                 Alex mercer
# 22698     4.3                            Self Opportunity
# 22699     3.8                                       Wipro
# 22707     4.6                 Regal Software Technologies
# 22748     4.2  Full Time Soluções em Serviços Financeiros
#
#                         Job Title   Salary  Salaries Reported   Location  \
# 2               Android Developer  1000000                  3  Bangalore
# 18              Android Developer  1000000                  2  Bangalore
# ...

# %%
df[df['Salary'] == df['Salary'].max()]
# Out:
#        Rating       Company Name                            Job Title  \
# 18635     3.6  Thapar University  Software Development Engineer (SDE)
#
#          Salary  Salaries Reported   Location Employment Status Job Roles
# 18635  90000000                  1  New Delhi         Full Time       SDE

# %%
df.groupby('Salaries Reported')['Salary'].mean()
# Out:
# Salaries Reported
# 1      6.998028e+05
# 2      6.643749e+05
# 3      7.149129e+05
# 4      7.610995e+05
# 5      6.806540e+05
#            ...
# 280    8.520000e+05
# 291    1.188000e+06
# 331    1.000000e+05
# 353    5.700000e+06
# 361    1.104000e+06
# Name: Salary, Length: 82, dtype: float64

# %%
df.groupby('Job Title').size()
# Out:
# Job Title
# "ORACLE DBA"                                 2
# .NET Developer, Python                       1
# .NET/Android Developer                       1
# AEM Front End Developer - Intern             1
# ASAP Software Development Engineer           1
#                                             ..
# Web Developer Contractor                    12
# Web Developer, Python Developer              1
# Web Developer/Android Developer - Intern     1
# Xamarin Mobile Developer                     1
# oracle dba                                   1
# Length: 1080, dtype: int64
